# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F


import numpy as np
import matplotlib.pyplot as plt

from utils import (get_train_mnist,
                   get_test_mnist, 
                   train,
                   test)

from plot import plot_weight_distribution

from args import args

# %% [markdown]
# ### Для начала обучим обычную модель, на датасете MNIST
# ### Сделаем все необходимые для этого импорты и подготовим код для обучения модели

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, 3, stride=1, bias=False)
        self.conv2 = nn.Conv2d(8, 8, 3, stride=5, bias=False)
        self.fc = nn.Linear(32, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = torch.flatten(x, 1)
        output = self.fc(x)
        return output

# %%
def train_and_eval(model, train_loader, test_loader):
    if args['cuda']:
        model.cuda()

    history = []
    loss_fn = torch.nn.CrossEntropyLoss(ignore_index=255)
    optimizer = optim.Adam(model.parameters(), lr=args['lr'])
    for epoch in range(1, args['epochs'] + 1):

        train(model, epoch, loss_fn, optimizer, train_loader)
        acc = test(model, loss_fn, optimizer, test_loader)
        history.append(acc)

    return acc

# %%
train_loader =  get_train_mnist()
test_loader= get_test_mnist()

# %%
model = SimpleCNN()
hist = train_and_eval(model, train_loader, test_loader)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.314539
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 1.950037
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 1.271178
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 1.001804
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.940927
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 0.877103
#
# Test set: Average loss: 0.0016, Accuracy: 7388/10000 (74%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.861978
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 0.762965
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 0.706322
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 0.750419
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.647002
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 0.689968
#
# Test set: Average loss: 0.0012, Accuracy: 8041/10000 (80%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.659893
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 0.620013
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 0.593453
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 0.522154
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 0.648952
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 0.588407
#
# Test set: Average loss: 0.0011, Accuracy: 8274/10000 (83%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.607544
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 0.530177
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 0.572148
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 0.479205
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.508721
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 0.554930
#
# Test set: Average loss: 0.0010, Accuracy: 8431/10000 (84%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.504387
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 0.512603
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 0.554690
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 0.537068
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 0.398294
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 0.541373
#
# Test set: Average loss: 0.0009, Accuracy: 8572/10000 (86%)

# %% [markdown]
# ## Квантизация

# %% [markdown]
# $$
# \frac{\partial \hat{v}}{\partial s} =
# \begin{cases}
# -\frac{v}{s} + \left\lfloor \frac{v}{s} \right\rceil & \text{if } -Q_N < \frac{v}{s} < Q_P, \\
# -Q_N & \text{if } \frac{v}{s} \leq -Q_N, \\
# Q_P & \text{if } \frac{v}{s} \geq Q_P.
# \end{cases}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Теперь мы хотим написать класс квантизатор, который будет квантизовать входящий тензор.
# ### Заметим что параметр S у нас будет обучамыем, но с другой стороны мы так же сможем его задать исходя из значений тензора.

# %%
class Quantizer(nn.Module):
    def __init__(self, bit):

        super(Quantizer, self).__init__()
        self.bit = bit
        self.thd_neg = -(2 ** (bit - 1))
        self.thd_pos = 2 ** (bit - 1) - 1
        self.s = nn.Parameter(torch.ones(1))

    def init_from(self, x):
        s = (x.max() - x.min()) / (self.thd_pos - self.thd_neg )
        self.s = nn.Parameter(s)

    def skip_grad_scale(self,x, scale):
        y = x
        y_grad = x * scale
        return (y - y_grad).detach() + y_grad

    # LSQ pass
    def round_pass(self, x):
        y = x.round()
        y_grad = x
        return (y - y_grad).detach() + y_grad

    def forward(self, x):
        if self.bit >= 32:
            return x

        s_grad_scale = 1.0 / ((self.thd_pos * x.numel()) ** 0.5)  # emperial  !!! ???
        device = x.device

        s_scale = self.skip_grad_scale(self.s, s_grad_scale).to(device)

        x = x / (s_scale)
        x = torch.clamp(x, self.thd_neg, self.thd_pos)
        x = self.round_pass(x)

        x = x * (s_scale)
        return x

# %% [markdown]
# ### Посмотрим на то как работает получившийся квантизатор

# %%
vector =(np.arange(-100, 100, 1))**2

vector = torch.tensor(vector)

plt.figure(figsize=(10,7))

f = plt.figure(figsize = (10, 5))

plt.plot(range(len(vector)), vector,label='orig', marker='o')
for bit in [2,3,4, 8, 16]:
    quantizer = Quantizer(bit)
    quantizer.init_from(vector)
    dequantized = quantizer(vector)

    dequantized = dequantized.detach().numpy()

    plt.plot(range(len(vector)),dequantized,label=f'int_{bit}')

plt.title('DE - Quantized');
plt.legend();

# %% [markdown]
# ### Небольшая функция для отрисовки гистограмм весов модели

# %%
plot_weight_distribution(model,Quantizer, bitwidth=8)
# Out:
# 3

# %%
plot_weight_distribution(model,Quantizer,bitwidth=4)
# Out:
# 3

# %% [markdown]
# ### Теперь напишем функции сверточного и линейного слоев которые поддерживают квантизацию

# %%
class QAConv2d(nn.Module):
    def __init__(self, bit, ch_in,ch_out, kernel=3, padding=0, stride=1):
        super(QAConv2d, self).__init__()
        self.bit = bit
        self.ch_in = ch_in
        self.ch_out = ch_out
        self.kernel = kernel
        self.padding = padding
        self.stride = stride
        self.conv = nn.Conv2d(ch_in, ch_out, kernel, stride, padding, bias=False)
        self.define_q_fucntions(self.bit)


    # can be used to modify bits during the training
    def define_q_fucntions(self, bit):
        self.quantizer_act = Quantizer(bit)
        self.quantizer_weight = Quantizer(bit)
        self.quantizer_weight.init_from(self.conv.weight)

    def forward(self, input_x):
        quantized_weight = self.quantizer_weight(self.conv.weight)
        quantized_act= self.quantizer_act(input_x)
        out = nn.functional.conv2d(quantized_act, quantized_weight, None, self.stride, self.padding)
        return out

class QALinear(nn.Module):
    def __init__(self, bit, ch_in,ch_out):
        super(QALinear, self).__init__()
        self.bit = bit
        self.ch_in = ch_in
        self.ch_out = ch_out
        self.fc = nn.Linear(ch_in, ch_out, bias=True)
        self.define_q_fucntions(self.bit)


    # can be used to modify bits during the training
    def define_q_fucntions(self, bit):
        self.quantizer_act = Quantizer(bit)
        self.quantizer_weigh = Quantizer(bit)
        self.quantizer_weigh.init_from(self.fc.weight)

        self.quantizer_bias = Quantizer(bit)

    def forward(self, input_x):
        quantized_bias = self.quantizer_bias(self.fc.bias)
        quantized_weight = self.quantizer_weigh(self.fc.weight)
        quantized_act = self.quantizer_act(input_x)
        out = nn.functional.linear(quantized_act, quantized_weight, bias=quantized_bias)
        return out

# %% [markdown]
# ### Объявим нашу модель с учетом этих слоев

# %%
class QuanSimpleCNN(nn.Module):
    def __init__(self, bit):
        super(QuanSimpleCNN, self).__init__()
        self.conv1 = QAConv2d(bit,1, 8, 3, stride=1)
        self.conv2 = QAConv2d(bit,8, 8, 3, stride=5)
        self.fc = QALinear(bit, 32, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        x = torch.flatten(x, 1)
        output = self.fc(x)
        return output

# %%
model = QuanSimpleCNN(32)
hist = train_and_eval(model, train_loader, test_loader)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.318240
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 1.787442
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 1.201084
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 0.940624
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.776467
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 0.704865
#
# Test set: Average loss: 0.0013, Accuracy: 7860/10000 (79%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.718195
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 0.647983
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 0.690525
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 0.617705
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.530254
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 0.548299
#
# Test set: Average loss: 0.0010, Accuracy: 8395/10000 (84%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.493509
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 0.452781
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 0.565407
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 0.466852
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 0.492561
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 0.470735
#
# Test set: Average loss: 0.0009, Accuracy: 8546/10000 (85%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.487320
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 0.434199
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 0.449724
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 0.460468
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.529780
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 0.441235
#
# Test set: Average loss: 0.0008, Accuracy: 8669/10000 (87%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.401374
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 0.437767
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 0.429850
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 0.444942
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 0.413415
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 0.429970
#
# Test set: Average loss: 0.0008, Accuracy: 8713/10000 (87%)

# %%
args['cuda'] = True

model = QuanSimpleCNN(2)
plot_weight_distribution(model,Quantizer, bitwidth=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 args['cuda'] = True
#       3 model = QuanSimpleCNN(2)
#       4 plot_weight_distribution(model,Quantizer, bitwidth=2)
#
# NameError: name 'args' is not defined

# %%
hist = train_and_eval(model, train_loader, test_loader)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302895
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 2.294511
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 2.143631
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 1.884079
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 1.609165
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 1.423288
#
# Test set: Average loss: 0.0026, Accuracy: 5769/10000 (58%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.271829
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 1.480604
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 1.144579
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 1.185586
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 1.190936
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 1.174289
#
# Test set: Average loss: 0.0022, Accuracy: 6313/10000 (63%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.122720
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 1.125480
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 1.181695
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 1.055597
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 1.078558
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 0.988458
#
# Test set: Average loss: 0.0019, Accuracy: 6723/10000 (67%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.945372
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 0.962635
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 1.016419
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 1.123958
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.938485
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 1.042712
#
# Test set: Average loss: 0.0020, Accuracy: 6669/10000 (67%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.980119
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 2.531856
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 1.844076
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 1.773047
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 1.335362
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 1.264263
#
# Test set: Average loss: 0.0022, Accuracy: 6169/10000 (62%)

# %%
plot_weight_distribution(model,Quantizer, bitwidth=2)
# Out:
# 3

# %%
model = QuanSimpleCNN(4)
hist = train_and_eval(model, train_loader, test_loader)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.319268
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 1.956903
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 1.614310
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 1.349588
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 1.091084
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 1.031898
#
# Test set: Average loss: 0.0017, Accuracy: 7148/10000 (71%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.927451
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 0.854797
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 0.847516
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 0.750218
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.794297
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 0.682465
#
# Test set: Average loss: 0.0013, Accuracy: 7910/10000 (79%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.737119
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 0.597582
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 0.662050
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 0.619413
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 0.807871
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 0.639270
#
# Test set: Average loss: 0.0012, Accuracy: 8134/10000 (81%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.527973
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 0.554950
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 0.887607
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 0.714343
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.632655
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 0.575808
#
# Test set: Average loss: 0.0011, Accuracy: 8203/10000 (82%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.661143
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 0.554780
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 0.617758
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 0.499330
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 0.609322
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 0.637226
#
# Test set: Average loss: 0.0011, Accuracy: 8254/10000 (83%)

# %%
args['cuda'] = True

model = QuanSimpleCNN(2)
hist = train_and_eval(model, train_loader, test_loader)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.302585
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 2.314795
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 2.188543
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 1.900020
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 1.594021
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 1.414534
#
# Test set: Average loss: 0.0027, Accuracy: 5498/10000 (55%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.364533
# Train Epoch: 2 [10000/60000 (17%)]	Loss: 1.351362
# Train Epoch: 2 [20000/60000 (33%)]	Loss: 1.327569
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 1.288578
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 1.252423
# Train Epoch: 2 [50000/60000 (83%)]	Loss: 1.274913
#
# Test set: Average loss: 0.0023, Accuracy: 6205/10000 (62%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.208413
# Train Epoch: 3 [10000/60000 (17%)]	Loss: 1.160928
# Train Epoch: 3 [20000/60000 (33%)]	Loss: 1.084088
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 1.163934
# Train Epoch: 3 [40000/60000 (67%)]	Loss: 1.275428
# Train Epoch: 3 [50000/60000 (83%)]	Loss: 1.081144
#
# Test set: Average loss: 0.0023, Accuracy: 6087/10000 (61%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.134084
# Train Epoch: 4 [10000/60000 (17%)]	Loss: 1.272105
# Train Epoch: 4 [20000/60000 (33%)]	Loss: 1.158844
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 1.145109
# Train Epoch: 4 [40000/60000 (67%)]	Loss: 0.994600
# Train Epoch: 4 [50000/60000 (83%)]	Loss: 1.064164
#
# Test set: Average loss: 0.0022, Accuracy: 6259/10000 (63%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 1.073990
# Train Epoch: 5 [10000/60000 (17%)]	Loss: 1.094155
# Train Epoch: 5 [20000/60000 (33%)]	Loss: 1.247906
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 1.203903
# Train Epoch: 5 [40000/60000 (67%)]	Loss: 1.311172
# Train Epoch: 5 [50000/60000 (83%)]	Loss: 1.209374
#
# Test set: Average loss: 0.0024, Accuracy: 6082/10000 (61%)

# %%
plot_weight_distribution(model,Quantizer,bitwidth=4)
# Out:
# 3

# %%
model.conv1.quantizer_act.s, model.conv1.quantizer_weight.s
# Out:
# (Parameter containing:
#  tensor([0.7154], requires_grad=True),
#  Parameter containing:
#  tensor(0.0935, requires_grad=True))
